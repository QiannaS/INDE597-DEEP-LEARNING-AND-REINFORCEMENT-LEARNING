# %% [markdown]
# Figure-1 is the picture after the first iteration, and we have assumptions as, nosie=0.2,discount =0.9.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Figure-2 is the result of the second iteration. But we have not determined the direction of each square since we need to try on the third iteration to find which direction of each square has the largest value, taking that direction as the final direction of the square in the second iteration.

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# Figure 3 is the process of finding the direction ( third iteration ).
#
# For (3,3), 0.78 is the largest value so we take the right as the direction of (3,3) in the second iteration. And taking the up as the direction of (3,2) since 0.43 is the largest one among those values

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# Figure 4 is the final result of the second iteration with the directions and values.
#
# For Figure-2, I can clearly calculate those values. Take(3,3) as an example.

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# For Figure-2,  Take(3,3) as an example.
#
# up:
#
# 80%going up:0.8∗0
#
# 10%going left; 0.1∗0
#
# 10%going right;0.1∗1
#
# Reward (up)= 0.9∗(0+0+0.1)=0.09
#
# down:
#
# 80%going down:0.8∗0
#
# 10%going left; 0.1∗0
#
# 10%going right;0.1∗1
#
# Reward (down)= 0.9∗(0+0+0.1)=0.09
#
# left:
#
# 80%going left:0.8∗0
#
# 10%going up; 0.1∗0
#
# 10%going down:0.1∗0
#
# Reward (down)= 0.9∗(0+0+0)=0
#
# right:
#
# 80%going right:0.8∗1
#
# 10%going up; 0.1∗0
#
# 10%going down:0.1∗0
#
# Reward (right)= 0.9∗(0.8+0+0)=0.72
#
# we take 0.72 as the value of (3,3) in the second iteration because it is the largest among the other three values.

# %% [markdown]
# In the same way,calculation the third iteration
# 0.78 = (0.8*1 + 0.1* 0.7) *0.9 = 0.78
